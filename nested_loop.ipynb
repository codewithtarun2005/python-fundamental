# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithtarun2005/python-fundamental/blob/main/nested_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for j in range(3):
 print("j=" ,j)

# %%
for row in range(4):

  for col in range(5):
   print("*",end = " ")
  print('')

# %%
for raw in range(7):
  for col in range(6):
    print("*",end = "")
  print("")

# %%
for i in range(1,6):
  for j in range(5):
   print(i,end = " ")
  print()

# %%
for j in range(5):
   for i in range(1,6):
    print(i*10,end = " ")
   print("")

# %%
for row in range(1,7):
 for col in range(row):
  print("*",end = " ")
 print()

# %%
for i in range(1,6):
  for j in range(1,i +1):
    print(j,end = " ")
  print()

# %%
for i in range(1,6):
 for j in range(1,i+1):
  print(j,end = " ")
 print()

# %%
n = 1
for row in range(1,5):
  for col in range(row):
    print(n,end = " ")
    n = n +1
  print()
