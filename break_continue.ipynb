# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithtarun2005/python-fundamental/blob/main/break_continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,11):
 print(i)

# %%
for i in range(1,11):
   if i == 5:
    break
   print(i)

# %%
password = "pass@345"
while True:
  p =input()

  if p == password:
    break

# %%
for i in range(1,11,2):
   if i ==6:
    break
   print(i)

# %%
for i in range(0,11,2):
   if i ==6:
    break
   print(i)

# %% [markdown]
# #continue

# %%
for i in range(1,10,1):
  if i == 5:
    break
  print(i)

# %%
for i in range(1,20,1):

  print(i)
  if i == 7:
    continue

# %%
for i in range(1,10,1):
  if i % 2 != 0:
     continue
  print(i)

# %%
for i in range(1,18):
  if i ==4:
    continue
  print(i)

# %%
  i = 1
  while i <= 10:
     if i == 7 :
        i = i+1

        continue
     print(i)
     i = i+1

# %%
# nested loop

# %%
for i in range(1,19):
  print("i","=",i)

# %%
for i in range(5):
  for j in range(3):
                 print("i=",i,"j=",j)

# %%
for row in range(4):

  for col in range(5):
    print("*", end = " ")
  print()

# %%
for row in range(5):
 for col in range(6):
    print("*",end = " ")
 print()

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i,end =" ")
  print()

# %%
for i in range(1,6):
  for j in range(1,6):
    print(j,end =" ")
  print()

# %%
for i in range(10,50,10):
  for j in range(10,50,10):
    print(j ,end = " ")
  print()

# %%
for row in range (1,6):
  for col in range(row):
    print(row , end = " ")

  print()

# %%
for i in range(1,11,2):
  print(i)
  i =i+1

# %%
print("hello world")
for i  in range (1,12,4):
   print(i)
   i = i+1
if range == 10:

 print(i)
i = i+1

# %%
for i in range(10):
  if i % 3 == 0:
    continue

  print(i)

# %%
for i in range(1,5):
  if i == 3:
   break
  print(i)

print("done")

# %%
num = int(input("enter a number"))
if num % 3 == 0:

   if num % 5 == 0:
    print("both")

   else:
     print("three")

# %%
for i in range(2,11,2):
  if i == 8:
    break
  print(i)

# %%
x = 7

if x == 4:
break:
print(x)
 x = -1

# %%
for ch in "python":
    if ch == "h":
        continue
    print(ch)

# %%
i = 1
while i <= 5:
  if i ==3:
     i += 1
     continue
  print(i)
  i += 1

# %%
marks = int(input("enter a number"))

if marks >= 90:
  print("a")
elif marks >= 75:
   print("b")
elif marks >= 60:
    print("c")
else:
      print("d")

# %%
for i in range(5):
   if i == 2:
     continue
   if i == 4:
     break
   print(i)

# %%
for i in range(1,11):
  if i % 2 == 0:
    continue
  if i > 7:
      break
  print(i)

# %%
i = 1
while i <= 5:
  if i == 3:
    i += 1
    continue
  print(i)
  i += 1

# %%
num = int(input("enter a number"))
if num  % 2 == 0:
  if num % 3 == 0:
    print("divisibel by both")
  else:
    print("only even")

else:
  print("odd")
