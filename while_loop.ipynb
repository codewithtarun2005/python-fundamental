# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithtarun2005/python-fundamental/blob/main/while_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 1
while i  <= 9:
  i =  i +1
  print(i)

# %%
i = 1
while i < 9:
  i = i +2
  print(i)

# %%
i = 7
while i>=1:
  print(i,"hello")
  i = i-1

# %%
#print all the even number \
i = 1
while i <= 10:
  if i % 2 == 0:
    print(i)
  i = i + 1

# %%
 #print 1 to 10 btw odd digit
 i = 0
while i <= 10:
  if i % 2 != 0:
    print(i)
  i = i+1

# %%
#print the sum of all 1 to 10 number
sum = 0
for i in range(1,11):
  sum += i
  print(sum)

# %%
sum = 0
i = 1
while i <= 10:
 sum += 1
i += 1

print(sum)

# %%
sum = 0
i = 1
sum += 1
i += 1
print(sum)

# %%
print("hello world")

# %%
print(5 + 9)

# %%
 sum = 0
 i = 0
 while <= 10:
  sum = +1
  print(sum)
  i = i+1

# %%
sum = 0
for i in range(1,11):
  sum += 1
  print(sum)

# %%
i = 1
while i <= 10:
  print(5,"*",i,"=",5*i)
  i += 1

# %%
i = 0
while i <= 10:
  print(5,"*",i,"=",5*i)
  i = i +1

# %%
p = ""
pasword = "pasword"

while p != pasword:
 p = input()

print("cotrrect pasword")

# %%
x = 0
while x <3:
 print(x)
 x += 1

print("done")

# %%
number = 1
while number <=5:
  if number %2 == 0:
    print(number)
  number += 1

# %%
count = 10
while count > 0:
 print(count)
 count -=1
